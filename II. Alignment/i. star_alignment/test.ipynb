# %%
import pandas as pd
import re
from pathlib import Path

# %%
current_path = Path.cwd()
subfolder = current_path/"subfolder"

# %%
input_bam_name = next(bam for bam in subfolder.glob("*_dedup.bam"))

input_bam_name

output_bam_name = subfolder/f"{input_bam_name.stem}_realigned.bam"

output_bam_name
# Out:
# WindowsPath('c:/Users/Sonia Ling/Desktop/new_pipeline/subfolder/test_dedup_realigned.bam')
